# %% [markdown]
# # Bibliotecas

# %%
import pandas as pd
import numpy as np
import psycopg2 as postgres
import psycopg2.extras
import csv
import random
#from sshtunnel import SSHTunnelForwarder
from tqdm import tqdm
import ast

# %% [markdown]
# # Funções

# %%
def executeQuery(conn, sql):
    record = None
    try:
        #print(sql)
        cur = conn.cursor(cursor_factory = psycopg2.extras.RealDictCursor)
        cur.execute(sql)
        record = cur.fetchall()
        cur.close()
    except postgres.Error as e:
        print(e)
        cur.execute("ROLLBACK")
        cur.close()
    return record

# %%
#Recebe um id e retorna as categorias e checkin do lugar
def getPOIInformation(conn, business_id):
    
    sql = """
        SELECT id, name FROM pois_information WHERE id  = \'"""+str(business_id)+ """\'
    ;"""

    result = executeQuery(conn, sql)

    return result

# %%
df_NYC = pd.read_csv("../dataset/NYC/NYC_train.csv")
df_NYC_ = df_NYC[["POI_id", "POI_catname"]]
df_NYC_.head()
# Out:
#                      POI_id          POI_catname
# 0  49bbd6c0f964a520f4531fe3  Arts & Crafts Store
# 1  4a43c0aef964a520c6a61fe3               Bridge
# 2  4c5cc7b485a1e21e00d35711       Home (private)
# 3  4ce1863bc4f6a35d8bd2db6c       Home (private)
# 4  4c0ab56f7e3fc9288c1df482    Mobile Phone Shop

# %%
df_NYC_.shape
# Out:
# (83228, 2)

# %%
df_NYC_ = df_NYC_.drop_duplicates()

# %%
df_NYC_.shape
# Out:
# (5083, 2)

# %%
def generate_path_corpus_all(df, bin_number, size):
    # Criar a janela ao redor do POI e unir as sentenças
    wnd = (bin_number + 1) * size

    file_name = './NYC-shortest_path-Copy2.csv'

    print("loading file:", file_name)
    all_pois_path = []
    with open(file_name, newline='') as f:
        csv_reader = csv.reader(f)
        for row in csv_reader:
            all_pois_path.append(row)

    file_name_corpus = './NYC-shortest_path_corpus-' + str(bin_number) + '-FT-c_gpu.csv'

    csv_file = open(file_name_corpus, "w", newline='')
    writer = csv.writer(csv_file, delimiter=',')
    writer.writerow([
        "poi_id_center",
        "center_poi",
        # "context_poi_id",
        "context_poi"
    ])

    for poi_path in tqdm([all_pois_path]):
        sub_path = list(range(0, wnd + 1))
        sub_path_types = []

        # Preenchendo lista inicial
        for sb_idx in sub_path:
            if sb_idx < len(poi_path):
                poi_id = poi_path[sb_idx]
                #poi_information = getPOIInformation(connection, poi_id)
                poi_information = df_NYC_[df_NYC_["POI_id"] == poi_id]

                if len(poi_information) > 0:
                    columns = ["POI_id","POI_catname"]
                    poi_information = pd.DataFrame(poi_information, columns=columns)
                    sub_path_types.append(poi_information)

        # Iniciando o processo de associações
        for i in range(len(poi_path)):
            # Associações binárias
            # sub_path[0] é o POI alvo
            target_types = sub_path_types[0]
            for j in range(1, len(sub_path_types)):
                neighbor_types = sub_path_types[j]

                for id_t, tg in target_types.iterrows():
                    for id_n, ng in neighbor_types.iterrows():
                        if tg['name'] != ng['name']:
                            line = [
                                str(tg['id']),
                                str(tg['name']),
                                # str(ng['id']),
                                str(ng['name']),
                            ]
                            writer.writerow(line)

            # break

            new_poi = i + (wnd) + 1
            sub_path.pop(0)
            sub_path.append(new_poi)
            sub_path_types.pop(0)

            if new_poi < len(poi_path):
                poi_id = poi_path[new_poi]
                poi_information = getPOIInformation(connection, poi_id)

                if len(poi_information) > 0:
                    columns = list(dict(poi_information[0]).keys())
                    poi_information = pd.DataFrame(poi_information, columns=columns)
                    sub_path_types.append(poi_information)

    csv_file.close()

# %%
for poi_path in tqdm([all_pois_path]):
        sub_path = list(range(0, 10))
        sub_path_types = []

        # Preenchendo lista inicial
        for sb_idx in sub_path:
            if sb_idx < len(poi_path):
                poi_id = poi_path[sb_idx]
                print(poi_id)
                #poi_information = getPOIInformation(connection, poi_id)
                poi_information = df_NYC_[df_NYC_["POI_id"] == poi_id]

                if len(poi_information) > 0:
                    columns = ["POI_id","POI_catname"]
                    poi_information = pd.DataFrame(poi_information, columns=columns)
                    sub_path_types.append(poi_information)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 104.29it/s]
# 49bbd6c0f964a520f4531fe3
# 4a43c0aef964a520c6a61fe3
# 4c5cc7b485a1e21e00d35711
# 4ce1863bc4f6a35d8bd2db6c
# 4c0ab56f7e3fc9288c1df482
# 4c00297392a6c9280cc243e2
# 4b9830a5f964a520c73235e3
# 4ba8a9a9f964a5206ee539e3
# 4c955b3558d4b60c06d03129
# 4ba0e0edf964a520138437e3

# %%
sub_path_types
# Out:
# [                     POI_id          POI_catname
#  0  49bbd6c0f964a520f4531fe3  Arts & Crafts Store,
#                       POI_id POI_catname
#  1  4a43c0aef964a520c6a61fe3      Bridge,
#                       POI_id     POI_catname
#  2  4c5cc7b485a1e21e00d35711  Home (private),
#                       POI_id     POI_catname
#  3  4ce1863bc4f6a35d8bd2db6c  Home (private),
#                       POI_id        POI_catname
#  4  4c0ab56f7e3fc9288c1df482  Mobile Phone Shop,
#                       POI_id      POI_catname
#  5  4c00297392a6c9280cc243e2  Automotive Shop,
#                       POI_id        POI_catname
#  6  4b9830a5f964a520c73235e3  Food & Drink Shop,
#                       POI_id          POI_catname
#  7  4ba8a9a9f964a5206ee539e3  Government Building,
#                       POI_id POI_catname
#  8  4c955b3558d4b60c06d03129       Ferry,
#                       POI_id POI_catname
#  9  4ba0e0edf964a520138437e3      Office]

# %%
poi_information
# Out:
#                      POI_id POI_catname
# 9  4ba0e0edf964a520138437e3      Office

# %%
all_pois_path[0]
# Out:
# '49bbd6c0f964a520f4531fe3'

# %%
alll

# %%
poi_id
# Out:
# '4'

# %%
generate_path_corpus_all(df_NYC_, 400, 1)
# Out:
# loading file: ./NYC-shortest_path-Copy2.csv
#   0%|          | 0/4981 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 generate_path_corpus_all(df_NYC_, 400, 1)
#
# Cell In[13], line 45, in generate_path_corpus_all(df, bin_number, size)
#      41 # Iniciando o processo de associações
#      42 for i in range(len(poi_path)):
#      43     # Associações binárias
#      44     # sub_path[0] é o POI alvo
# ---> 45     target_types = sub_path_types[0]
#      46     for j in range(1, len(sub_path_types)):
#      47         neighbor_types = sub_path_types[j]
#
# IndexError: list index out of range

# %%
import csv
from tqdm import tqdm
import pandas as pd

def generate_path_corpus_zoning_all(all_pois_path, size):
    # Criar a janela ao redor do POI e unir as sentenças
    wnd = size

    file_name_corpus = './NYC-shortest_path.csv'
    
    csv_file = open(file_name_corpus, "w", newline='')
    writer = csv.writer(csv_file, delimiter=',')
    writer.writerow(["poi_id_center", "center_poi", "context_poi"])

    for index, poi_path in enumerate(tqdm(all_pois_path)):
        sub_path = list(range(0, wnd + 1))
        sub_path_types = []

        # Preenchendo lista inicial
        for sb_idx in sub_path:
            if sb_idx < len(poi_path):
                poi_id = poi_path[sb_idx]
                poi_information = df_NYC_[df_NYC_["POI_id"] == poi_id]

                if len(poi_information) > 0:
                    columns = list(dict(poi_information.iloc[0]).keys())
                    poi_information = pd.DataFrame(poi_information, columns=columns)
                    sub_path_types.append(poi_information)

        # Iniciando o processo de associações
        for i in range(len(poi_path)):
            if len(sub_path_types) > 0:
                target_types = sub_path_types[0]
                for j in range(1, len(sub_path_types)):
                    neighbor_types = sub_path_types[j]

                    for id_t, tg in target_types.iterrows():
                        for id_n, ng in neighbor_types.iterrows():
                            if tg['name'] != ng['name']:
                                line = [
                                    str(tg['id']), 
                                    str(tg['name']),
                                    str(ng['name'])
                                ]
                                writer.writerow(line)

                new_poi = i + wnd + 1
                sub_path.pop(0)
                sub_path.append(new_poi)
                sub_path_types.pop(0)

                if new_poi < len(poi_path):
                    poi_id = poi_path[new_poi]
                    poi_information = getPOIInformation(connection, poi_id)

                    if len(poi_information) > 0:
                        columns = list(dict(poi_information.iloc[0]).keys())
                        poi_information = pd.DataFrame(poi_information, columns=columns)
                        sub_path_types.append(poi_information)

# %%
generate_path_corpus_zoning_all(,10)
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 generate_path_corpus_zoning_all(1,10)
#
# Cell In[14], line 15, in generate_path_corpus_zoning_all(all_pois_path, size)
#      12 writer = csv.writer(csv_file, delimiter=',')
#      13 writer.writerow(["poi_id_center", "center_poi", "center_poi_level", "context_poi", "context_poi_level"])
# ---> 15 for index, poi_path in enumerate(tqdm(all_pois_path)):
#      16     sub_path = list(range(0, wnd + 1))
#      17     sub_path_types = []
#
# File ~/poi-recommendation-TCC/poi-sr/lib/python3.10/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# # Leitura de Dados

# %%
bin_number = 0
#file_name = './geographic/SHORTEST PATH/austin-shortest_path-' + str(bin_number) + '-CF-c.csv'
#file_name = './geographic/SHORTEST PATH/austin-shortest_path-' + str(bin_number) + '-FT-c_gpu.csv'
#file_name = './geographic/SHORTEST PATH/austin-shortest_path-zoning-FT_gpu.csv'
#file_name = './Atlanta/Shortest Path/atlanta-shortest_path-zoning-FT_gpu.csv'
#file_name = './Boston/Shortest Path/boston-shortest_path-zoning-FT_gpu.csv'
#file_name = './Boston/Shortest Path/boston-neighborhood-shortest_path-zoning-FT_gpu.csv'
file_name = './NYC-shortest_path-Copy2.csv'


print("loading file:", file_name)
all_pois_path = []
with open(file_name, newline='') as f:
    csv_reader = csv.reader(f)
    for row in csv_reader:
        if len(row) > 0:
            all_pois_path.append(row)
        
print(len(all_pois_path))
# Out:
# loading file: ./NYC-shortest_path-Copy2.csv
# 4981

# %%
all_pois_path.pop(0)
# Out:
# ['ID']

# %%
#REMOVENDO DUPLICADAS
import itertools
all_pois_path = list(k[0] for k,_ in itertools.groupby(all_pois_path))

# %%
len(all_pois_path)
# Out:
# 4980

# %%
len('49bbd6c0f964a520f4531fe3')
# Out:
# 24

# %%
all_pois_path
# Out:
# ['49bbd6c0f964a520f4531fe3',
#  '4a43c0aef964a520c6a61fe3',
#  '4c5cc7b485a1e21e00d35711',
#  '4ce1863bc4f6a35d8bd2db6c',
#  '4c0ab56f7e3fc9288c1df482',
#  '4c00297392a6c9280cc243e2',
#  '4b9830a5f964a520c73235e3',
#  '4ba8a9a9f964a5206ee539e3',
#  '4c955b3558d4b60c06d03129',
#  '4ba0e0edf964a520138437e3',
#  '4a676ff4f964a5206fc91fe3',
#  '4c5ef77bfff99c74eda954d3',
#  '4bcde547511f95210d62b5c7',
#  '3fd66200f964a52035e41ee3',
#  '4b3a8e5df964a520d86925e3',
#  '4b55ec3bf964a520aaf627e3',
#  '40b68100f964a5207d001fe3',
#  '4bf5cedf4d5f20a1833d98fe',
#  '40e74880f964a520150a1fe3',
#  '4ad607d3f964a520a10421e3',
#  '49b15042f964a520d4521fe3',
#  '4ca66eec5a1e952129d98ace',
#  '4c79b79381bca093e689fe14',
#  '447bf8f1f964a520ec331fe3',
#  '4dbdebed6e810768bf82ad95',
#  '4e79392ce4cdb158f1cf4b75',
#  '4bdb4bf54b1f952169ac670b',
#  '4b093cd0f964a520db1423e3',
#  '4c17d9974ff90f47a9890d49',
#  '4ab11744f964a520046820e3',
#  '4b298573f964a52050a024e3',
#  '4c1d0f98c09ed13ad4c5828e',
#  '4b7c9fe1f964a520559e2fe3',
#  '4a7a0832f964a5203ce81fe3',
#  '4e5dbf1e1f6e3022a71c242b',
#  '4c56f9ad30d82d7f3cbcd862',
#  '4d4de33cd6f3224bca73a1a6',
#  '4c62bfd0e1621b8dfe232453',
#  '4b8d2387f964a520dbe932e3',
#  '4c1a2bbf838020a1adc4e661',
#  '4af42a00f964a52055f021e3',
#  '4b565676f964a520120c28e3',
#  '4c3b49c54565e21eb775566a',
#  '462a6065f964a520d9451fe3',
#  '4a8ae51ef964a520c10a20e3',
#  '45c76421f964a52066421fe3',
#  '4cd1a3d601eaf04db979bf5d',
#  '4c3a1d102c8020a1f9d58d00',
#  '4bbfcfd3461576b0d4487932',
#  '4ee6e1970e61681b98844283',
#  '4c0b32d37e3fc928650bf582',
#  '4cd544d894848cfa6a0de5b1',
#  '43695300f964a5208c291fe3',
#  '4b4b7979f964a520249d26e3',
#  '4df53b7bd4c01ff6b2f262ec',
#  '4eb4ce184901cef9d84576f8',
#  '4c81086adc018cfaa883c16c',
#  '40abf500f964a52035f31ee3',
#  '4caf3aa3b4b0a35db3273fce',
#  '4f67c6d5e4b0e34eb630101a',
#  '4459d2f1f964a520d7321fe3',
#  '4b4bb51df964a520c5a426e3',
#  '49f3a34cf964a520cd6a1fe3',
#  '49f39d66f964a520c06a1fe3',
#  '4cae1f8a1463a143d0ff89a9',
#  '4d900c2e1716a143175d59f7',
#  '4afb2990f964a520a91b22e3',
#  '3fd66200f964a520b9e51ee3',
#  '4b203d47f964a5202e2f24e3',
#  '42717900f964a5206f211fe3',
#  '4e6e3d8f18380b4aac553e9f',
#  '408c5100f964a520c6f21ee3',
#  '4a9f2373f964a520ab3c20e3',
#  '4dd7c0afd1647fcf3e518ff3',
#  '4c2603d9905a0f47456c6260',
#  '4e6b670f45ddadf2d0e3002d',
#  ...]

# %%
avg = 0
max_path = -np.inf
min_path = np.inf
path_sizes = []
counter_90 = 0
for path in all_pois_path:
    path_sizes.append(len(path[0]))
    if(len(path) >= 90):
        counter_90 += 1
    if (len(path) > max_path):
        max_path = len(path)
    elif(len(path) < min_path):
        min_path = len(path)
    avg += len(path)

print('comprimento máximo:', max_path)
print('comprimento mínimo:', min_path)
print('média de comprimento:', avg/len(all_pois_path))
print('mediana do comprimento:', np.median(path_sizes))
print('quantidade de caminhos acima de 90:', counter_90, 'de', len(all_pois_path))
# Out:
# comprimento máximo: 24
# comprimento mínimo: 24
# média de comprimento: 24.0
# mediana do comprimento: 1.0
# quantidade de caminhos acima de 90: 0 de 4980

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Ajustar o tamanho da figura (aumentar o comprimento)
plt.figure(figsize=(15, 5))  # Largura 10, altura 5

# Criar o boxplot na horizontal
plt.boxplot(path_sizes, vert=False)
plt.ylabel("Tamanhos")

min_val, max_val = min(path_sizes), max(path_sizes)
plt.xticks(np.arange(min_val - 1, max_val + 2, 50))  # Ticks de 1 em 1


# Exibir o gráfico
plt.show()

# %% [markdown]
# # Geração das Sentenças

# %%
#Escolhe aleatoreamente um tipo para compor a sentença
for rnd in range(0, 12):

    with SSHTunnelForwarder(
    ('150.165.15.171', 23456),
    #ssh_private_key="</path/to/private/ssh/key>",
    ### in my case, I used a password instead of a private key
    ssh_username="salatiel",
    ssh_password="Salatiel@Lacina123", 
    remote_bind_address=('localhost', 5432)) as server:

        server.start()
        #print("server connected")

        params = {'database': 'austin_test',
               'user': 'salatiel',
               'password': 'root',
               'host': 'localhost',
               'port': server.local_bind_port
        }

        connection = psycopg2.connect(**params)

        all_sentences = []

        for poi_path in tqdm(all_pois_path):
        #for poi_path in all_pois_path:
            poi_path_sentence = [] 
            for poi_id in poi_path: 
                #Obtendo informações de categorias e checkin do poi central
                #[business_id, checkin, category]
                poi_information = getPOIInformation(connection, poi_id)

                if (len(poi_information) > 0):

                    columns = list(dict(poi_information[0]).keys())
                    poi_information = pd.DataFrame(poi_information, columns = columns)

                    type_by_level = []

                    for level in range(5):

                        level_poi_information = poi_information[poi_information['level'] == level]
                        poi_types = list(level_poi_information['name'])
                        if (len(poi_types) > 0):
                            poi_type = poi_types[random.randint(0, len(poi_types)-1)]
                            type_by_level.append(poi_type)

                    #Selecionar aleatoreamente entre todos os tipos
                    selected_type = type_by_level[random.randint(0, len(type_by_level)-1)]
                    #print(type_by_level, selected_type)
                    poi_path_sentence.append(selected_type)


            all_sentences.append(poi_path_sentence)
            
    #file_name = './geographic/SHORTEST PATH/austin-shortest_path_corpus-' + str(bin_number) + '-rnd'+str(rnd)+'-CF-c.csv'
    file_name = './geographic/SHORTEST PATH/austin-shortest_path_corpus-' + str(bin_number) + '-rnd'+str(rnd)+'-FT-c.csv'

    csv_file_02 = open(file_name, "w", newline='')
    writer_path = csv.writer(csv_file_02, delimiter=',')
    for st in all_sentences:
        writer_path.writerow(st)
# Out:
# 100%|██████████| 22399/22399 [20:30<00:00, 18.20it/s]
# 100%|██████████| 22399/22399 [20:25<00:00, 18.28it/s]
# 100%|██████████| 22399/22399 [20:33<00:00, 18.16it/s]
# 100%|██████████| 22399/22399 [20:29<00:00, 18.22it/s]
#  65%|██████▍   | 14473/22399 [13:19<08:16, 15.97it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
#  72%|███████▏  | 16060/22399 [14:46<08:43, 12.10it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # Execução em Paralelo

# %%
#Quantidade de tuplas de vizinhos nos dados do yelp (center, context) considerando d = 100m
pois_file_name = './austin-ml-updated.csv'
poi_df = pd.read_csv(pois_file_name)
print(poi_df.shape)
poi_df = poi_df.dropna()
print(poi_df.shape)
poi_df.head()
# Out:
# (22399, 7)
# (22399, 7)
#               business_id    city state   latitude  longitude  \
# 0  N3_Gs3DnX4k9SgpwJxdEfw  Austin    TX  30.346169 -97.711458
# 1  tXvdYGvlEceDljN8gt2_3Q  Austin    TX  30.172706 -97.799920
# 2  nTIhpR7MhsALPwg_Hh14EA  Austin    TX  30.326377 -97.704543
# 3  8XyEpVdAO0o6iVkVxkWosQ  Austin    TX  30.246465 -97.778738
# 4  NVfOn7TdnHbaGH97CVB_Qg  Austin    TX  30.244902 -97.857409
#
#                                           categories  checkin_count
# 0  Shopping, Jewelry Repair, Appraisal Services, ...             14
# 1                             Barbers, Beauty & Spas              1
# 2  Hotels, Hotels & Travel, Event Planning & Serv...            475
# 3    Home Services, Real Estate, Property Management              0
# 4                    Chiropractors, Health & Medical             33

# %%
import multiprocessing as mp
print("Number of processors: ", mp.cpu_count())

# Step 1: Init multiprocessing.Pool()
pool = mp.Pool(int(mp.cpu_count()))


# Step 2: `pool.apply` the `howmany_within_range()`

# bins = [6, 7, 8]
# size = 10

#pool.starmap(generate_path_corpus_tg_cf, [(poi_df, n, size) for n in bins])

#size = [10, 20, 30, 40, 50]
size = [60, 70, 80, 90]


pool.starmap(generate_path_corpus_zoning_all, [(all_pois_path, sz) for sz in size])


# Step 3: Don't forget to close
pool.close()

#Para point
#calculateBinOSMPoints_Disco(df, n)
# Out:
# Number of processors:  20
# 100%|██████████| 1347/1347 [46:31<00:00,  2.07s/it]
# 100%|██████████| 1347/1347 [50:30<00:00,  2.25s/it]
# 100%|██████████| 1347/1347 [54:01<00:00,  2.41s/it]
# 100%|██████████| 1347/1347 [57:47<00:00,  2.57s/it]

# %%
all_pois_path[7][574]
# Out:
# '9_BYb_jBVb92bhQnRmCOjQ'
